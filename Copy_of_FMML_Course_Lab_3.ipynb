# %% [markdown]
# <a href="https://colab.research.google.com/github/tulasi-chinninti/fmml-projects-and-labs/blob/main/Copy_of_FMML_Course_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-16 13:26:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   190MB/s    in 0.4s
#
# 2022-06-16 13:26:13 (190 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2452 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3275 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 158  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 5  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 8914   1704.03520v2  Process mining analyzes business processes bas...    cs
# 31058  1802.02375v1  This paper proposes a powerful regularization ...    cs
# 26577  1611.03318v1  Unmanned aerial vehicles now make it possible ...    cs
# 10305   1111.5648v1  We information-theoretically reformulate two m...  stat
# 22763  1706.01807v1  This short article revisits some of the ideas ...  stat
# ...             ...                                                ...   ...
# 5378    1306.2733v2  The \emph{Mixed-Membership Stochastic Blockmod...    cs
# 26999  1701.08237v1  In this work, we present an algebraic solution...    cs
# 5923    1302.4389v4  We consider the problem of designing models to...  stat
# 7417   1712.06695v1  Estimators computed from adaptively collected ...  stat
# 22928  1711.01796v2  Sparse regularization such as $\ell_1$ regular...  stat
#
#                                                    title  year  \
# 8914   Unsupervised Event Abstraction using Pattern A...  2017
# 31058                           ShakeDrop regularization  2018
# 26577  Variables effecting photomosaic reconstruction...  2016
# 10305               Falsification and future performance  2011
# 22763  GAN and VAE from an Optimal Transport Point of...  2017
# ...                                                  ...   ...
# 5378   Copula Mixed-Membership Stochastic Blockmodel ...  2013
# 26999  An Efficient Algebraic Solution to the Perspec...  2017
# 5923                                     Maxout Networks  2013
# 7417       Accurate Inference for Adaptive Linear Models  2017
# 22928  Independently Interpretable Lasso: A New Regul...  2017
#
#                                                 keywords
# 8914   [process, mining, analyzes, business, processe...
# 31058  [proposes, powerful, regularization, method, s...
# 26577  [unmanned, aerial, vehicles, possible, obtain,...
# 10305  [information, theoretically, reformulate, meas...
# 22763  [article, revisits, introduced, simple, lights...
# ...                                                  ...
# 5378   [emphmixed, membership, stochastic, blockmodel...
# 26999  [present, algebraic, solution, classical, pers...
# 5923   [consider, problem, designing, models, leverag...
# 7417   [estimators, computed, adaptively, collected, ...
# 22928  [sparse, regularization, regularization, power...
#
# [4581 rows x 6 columns]

# %%
df['keywords']
# Out:
# 8914     [process, mining, analyzes, business, processe...
# 31058    [proposes, powerful, regularization, method, s...
# 26577    [unmanned, aerial, vehicles, possible, obtain,...
# 10305    [information, theoretically, reformulate, meas...
# 22763    [article, revisits, introduced, simple, lights...
#                                ...
# 3500     [generative, adversarial, networks, produce, s...
# 22130    [nonparametric, methods, increasingly, explore...
# 9410     [causal, effect, estimation, observational, im...
# 8503     [principal, component, analysis, fundamental, ...
# 5694     [consider, active, supervised, learning, offli...
# Name: keywords, Length: 5727, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 15500 words.
# Out of those 423 have over 158 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ae626d93-2833-45cc-90d1-4c6a82a33f8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae626d93-2833-45cc-90d1-4c6a82a33f8e")) {                    Plotly.newPlot(                        "ae626d93-2833-45cc-90d1-4c6a82a33f8e",                        [{"x":["common","processes","methods","however","quality","clustering","propose","higher","unsupervised","better","several","process","generate","models","existing","obtained","results","techniques","efficient","experiments","output","factor","datasets","multiple","powerful","important","effectiveness","feature","training","applied","proposes","regularization","method","learning","memory","convolutional","obtain","variables","approach","simple","application","including","single","specifically","problems","structure","presented","images","solutions","various","possible","building","processing","useful","particular","measures","future","performance","optimal","theory","complexity","statistical","probability","distribution","dataset","called","classifier","empirical","number","algorithm","information","networks","introduced","between","variational","generative","adversarial","gaussian","recent","moreover","estimate","finally","guarantees","source","significantly","likelihood","problem","faster","popular","require","result","provide","search","theoretical","representation","contrast","developed","sparse","framework","standard","language","independent","dimensional","solution","estimates","bayesian","comparison","develop","underlying","estimation","interest","inference","generalization","network","practical","making","neural","without","effective","address","widely","different","benchmark","evaluate","highly","proposed","applications","ability","specific","present","synthetic","studied","extensive","properties","system","experimental","design","finding","general","minimization","solving","explore","either","research","numerical","similar","examples","compare","algorithms","parameter","procedure","support","generalized","challenging","extend","demonstrate","further","additional","regression","signal","sparsity","selection","adaptive","parameters","choice","analysis","setting","provides","optimization","original","classification","machine","natural","limited","approaches","although","approximate","traditional","complex","predictive","technique","values","spatial","prediction","gradient","function","improve","combination","convergence","capture","demonstrated","accuracy","during","classes","features","detect","detection","associated","sampling","probabilistic"],"y":[129,76,604,413,193,99,743,93,112,283,296,273,121,556,292,160,821,250,273,418,106,62,320,245,72,261,152,269,414,209,94,65,704,851,102,266,105,106,730,244,168,166,205,114,354,221,154,385,94,232,184,85,188,111,188,64,91,587,171,141,163,131,116,145,303,168,94,104,363,557,477,461,72,474,39,82,59,77,222,102,77,174,43,98,181,50,652,79,127,102,166,282,167,120,245,95,155,107,354,169,247,103,147,161,48,95,105,110,80,127,105,141,66,532,96,112,515,211,164,159,86,535,142,159,111,651,274,106,168,490,107,69,135,141,393,274,152,69,239,47,98,87,94,218,61,145,92,132,387,80,74,123,54,185,61,376,193,72,84,60,41,109,75,170,45,390,93,159,211,100,352,275,209,105,311,75,80,126,162,36,169,94,97,146,96,264,198,102,83,100,70,311,124,88,378,87,255,71,73,113],"type":"bar"},{"x":["common","processes","methods","however","quality","clustering","propose","higher","unsupervised","better","several","process","generate","models","existing","obtained","results","techniques","efficient","experiments","output","factor","datasets","multiple","powerful","important","effectiveness","feature","training","applied","proposes","regularization","method","learning","memory","convolut ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (423,), (423, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.5767888307155323

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Modeling</span> <span style=''>meaning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>interpreting</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>natural</span> <span style='background-color:rgba(0, 255, 0, 0.5107033639143731);'>language</span> <span style=''>fragments</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>introductory</span> <span style=''>article</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>present</span> <span style=''>the</span> <span style=''>basics</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approach</span> <span style=''>to</span> <span style=''>implementing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>interpreting</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>natural</span> <span style='background-color:rgba(0, 255, 0, 0.5107033639143731);'>language</span> <span style=''>aiming</span> <span style=''>to</span> <span style=''>model</span> <span style=''>the</span> <span style=''>meanings</span> <span style=''>of</span> <span style=''>words</span> <span style=''>and</span> <span style=''>phrases</span> <span style=''>Unlike</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>we</span> <span style=''>attempt</span> <span style=''>to</span> <span style=''>define</span> <span style=''>the</span> <span style=''>meanings</span> <span style=''>of</span> <span style=''>text</span> <span style=''>fragments</span> <span style=''>in</span> <span style=''>a</span> <span style=''>composable</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3079847908745246);'>computer</span> <span style=''>interpretable</span> <span style=''>way</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discuss</span> <span style='background-color:rgba(255, 0, 0, 0.3173726212400246);'>models</span> <span style=''>and</span> <span style=''>ideas</span> <span style=''>for</span> <span style=''>detecting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7209302325581395);'>semantic</span> <span style=''>incomprehension</span> <span style=''>and</span> <span style=''>choosing</span> <span style=''>the</span> <span style=''>interpretation</span> <span style=''>that</span> <span style=''>makes</span> <span style=''>most</span> <span style=''>sense</span> <span style=''>in</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>context</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representation</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designed</span> <span style=''>for</span> <span style=''>handling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>context</span> <span style=''>sensitive</span> <span style=''>and</span> <span style=''>uncertain</span> <span style=''>imprecise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>knowledge</span> <span style=''>and</span> <span style=''>for</span> <span style=''>easy</span> <span style=''>accommodation</span> <span style=''>of</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>It</span> <span style=''>stores</span> <span style=''>quantitative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>causal</span> <span style=''>orders</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>linear</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Gaussian</span> <span style=''>acyclic</span> <span style=''>model</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>against</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>latent</span> <span style=''>confounders</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consider</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>causal</span> <span style=''>ordering</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>linear</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Gaussian</span> <span style=''>acyclic</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>called</span> <span style=''>LiNGAM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methods</span> <span style=''>have</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>consistently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimate</span> <span style=''>a</span> <span style=''>causal</span> <span style=''>ordering</span> <span style=''>assuming</span> <span style=''>that</span> <span style=''>all</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>are</span> <span style=''>correct</span> <span style=''>But</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>results</span> <span style=''>could</span> <span style=''>be</span> <span style=''>distorted</span> <span style=''>if</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>actually</span> <span style=''>are</span> <span style=''>violated</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style=''>causal</span> <span style=''>orders</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>against</span> <span style=''>one</span> <span style=''>typical</span> <span style=''>violation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>latent</span> <span style=''>confounders</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>method</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Normalized</span> <span style='background-color:rgba(255, 0, 0, 0.5460992907801419);'>Gradient</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3212669683257919);'>Adaptive</span> <span style=''>Stepsize</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Method</span> <span style=''>for</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Training</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propose</span> <span style=''>a</span> <span style=''>generic</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simple</span> <span style=''>algorithmic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3980028530670471);'>optimization</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>essentially</span> <span style=''>contains</span> <span style=''>two</span> <span style=''>consecutive</span> <span style=''>steps</span> <span style=''>in</span> <span style=''>each</span> <span style=''>iteration</span> <span style=''>1)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>and</span> <span style=''>normalizing</span> <span style=''>the</span> <span style=''>mini</span> <span style=''>batch</span> <span style='background-color:rgba(255, 0, 0, 0.5936794582392777);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.5460992907801419);'>gradient</span> <span style=''>2)</span> <span style=''>selecting</span> <span style='background-color:rgba(255, 0, 0, 0.3212669683257919);'>adaptive</span> <span style=''>step</span> <span style=''>size</span> <span style=''>to</span> <span style=''>update</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decision</span> <span style='background-color:rgba(255, 0, 0, 0.5570032573289901);'>variable</span> <span style=''>(parameter)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>towards</span> <span style=''>the</span> <span style=''>negative</span> <span style=''>of</span> <span style=''>the</span> <span style=''>normalized</span> <span style='background-color:rgba(255, 0, 0, 0.5460992907801419);'>gradient</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approach</span> <span style=''>when</span> <span style=''>customized</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3212669683257919);'>adaptive</span> <span style=''>stepsize</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>AdaGrad</span> <span style=''>can</span> <span style=''>enjoy</span> <span style=''>a</span> <span style=''>sublinear</span> <span style='background-color:rgba(255, 0, 0, 0.5677083333333333);'>convergence</span> <span style=''>rate</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.5889570552147239);'>convex</span> <span style=''>We</span> <span style=''>also</span> <span style=''>conduct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensive</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Embedded</span> <span style=''>Real</span> <span style=''>Time</span> <span style=''>Fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>Using</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Learning</span> <span style=''>For</span> <span style=''>Elderly</span> <span style=''>Care</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proposes</span> <span style=''>a</span> <span style=''>real</span> <span style=''>time</span> <span style=''>embedded</span> <span style=''>fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>system</span> <span style=''>using</span> <span style=''>a</span> <span style=''>DVS(Dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Vision</span> <span style=''>Sensor)</span> <span style=''>that</span> <span style=''>has</span> <span style=''>never</span> <span style=''>been</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dataset</span> <span style=''>for</span> <span style=''>fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>using</span> <span style=''>that</span> <span style=''>and</span> <span style=''>a</span> <span style=''>DVS</span> <span style=''>TN(DVS</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Temporal</span> <span style=''>Network)</span> <span style=''>The</span> <span style=''>first</span> <span style=''>contribution</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>building</span> <span style=''>a</span> <span style=''>DVS</span> <span style=''>Falls</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dataset</span> <span style=''>which</span> <span style=''>made</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>network</span> <span style=''>to</span> <span style=''>recognize</span> <span style=''>a</span> <span style=''>much</span> <span style=''>greater</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variety</span> <span style=''>of</span> <span style=''>falls</span> <span style=''>than</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>datasets</span> <span style=''>that</span> <span style=''>existed</span> <span style=''>before</span> <span style=''>and</span> <span style=''>solved</span> <span style=''>privacy</span> <span style=''>issues</span> <span style=''>using</span> <span style=''>the</span> <span style=''>DVS</span> <span style=''>Secondly</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>DVS</span> <span style=''>TN</span> <span style=''>optimized</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>network</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detect</span> <span style=''>falls</span> <span style=''>using</span> <span style=''>DVS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Finally</span> <span style=''>we</span> <span style=''>implemented</span> <span style=''>a</span> <span style=''>fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>system</span> <span style=''>which</span> <span style=''>can</span> <span style=''>run</span> <span style=''>on</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	semantic (0.09516460905349794)
# 	neural (0.264917695473251)
# 	object (0.10493827160493827)
# 	different (0.2752057613168724)
# 	convolutional (0.1368312757201646)
# 	recognition (0.13220164609053497)
# 	network (0.2736625514403292)
# 	language (0.12705761316872427)
# 	system (0.2021604938271605)
# 	images (0.19804526748971193)
#
# Some Statistics words are:
# 	algorithm (0.39362912400455063)
# 	estimation (0.1725445582100872)
# 	learning (0.5494880546075085)
# 	linear (0.22563519150549868)
# 	bayesian (0.16837315130830488)
# 	models (0.4069017823284035)
# 	inference (0.19416003033750473)
# 	dimensional (0.19795221843003413)
# 	gaussian (0.16306408797876373)
# 	regression (0.1831626848691695)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a21752ba-bd53-44bd-a426-31b394908d05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a21752ba-bd53-44bd-a426-31b394908d05")) {                    Plotly.newPlot(                        "a21752ba-bd53-44bd-a426-31b394908d05",                        [{"x":["common","processes","methods","however","quality","clustering","propose","higher","unsupervised","better","several","process","generate","models","existing","obtained","results","techniques","efficient","experiments","output","factor","datasets","multiple","powerful","important","effectiveness","feature","training","applied","proposes","regularization","method","learning","memory","convolutional","obtain","variables","approach","simple","application","including","single","specifically","problems","structure","presented","images","solutions","various","possible","building","processing","useful","particular","measures","future","performance","optimal","theory","complexity","statistical","probability","distribution","dataset","called","classifier","empirical","number","algorithm","information","networks","introduced","between","variational","generative","adversarial","gaussian","recent","moreover","estimate","finally","guarantees","source","significantly","likelihood","problem","faster","popular","require","result","provide","search","theoretical","representation","contrast","developed","sparse","framework","standard","language","independent","dimensional","solution","estimates","bayesian","comparison","develop","underlying","estimation","interest","inference","generalization","network","practical","making","neural","without","effective","address","widely","different","benchmark","evaluate","highly","proposed","applications","ability","specific","present","synthetic","studied","extensive","properties","system","experimental","design","finding","general","minimization","solving","explore","either","research","numerical","similar","examples","compare","algorithms","parameter","procedure","support","generalized","challenging","extend","demonstrate","further","additional","regression","signal","sparsity","selection","adaptive","parameters","choice","analysis","setting","provides","optimization","original","classification","machine","natural","limited","approaches","although","approximate","traditional","complex","predictive","technique","values","spatial","prediction","gradient","function","improve","combination","convergence","capture","demonstrated","accuracy","during","classes","features","detect","detection","associated","sampling","probabilistic","representations","latent","posterior","distributed","predictions","variable","binary","should","challenge","improves","allows","dimension","computational","computation","similarity","significant","patterns","random","efficiently","functions","stochastic","metric","outperforms","linear","programming","previous","arbitrary","hierarchical","accurate","consider","discrete","strategy","maximum","matrix","graphical","provided","construct","distributions","global","assumptions","simulated","potential","superior","estimating","alternative","assumption","perform","structured","approximation","rather","current","architecture","computer","towards","particularly","compared","descent","points","convex","measure","sequence","typically","finite","predict","generated","classical","within","conditions","behavior","derived","machines","recently","domains","architectures","achieved","achieve","structures","introduce","series","markov","vector","simulation","matrices","corresponding","hidden","sample","therefore","target","example","related","scheme","nonlinear","compute","estimator","requires","component","improved","variance","efficiency","embedding","computin ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
#
# Some words which never appear in Statistics papers:

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 0.006091728339122992

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.575043630017452
